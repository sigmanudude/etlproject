# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo
import pandas as pd
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist

# %%
# File to Load (Remember to Change These)
file_to_load = "~/Desktop/TMDB_Cleaned.csv"

# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(file_to_load)

df.head()
# Out:
#    Unnamed: 0                      title    budget  popularity  \
# 0        2772  The Widow of Saint-Pierre         0    1.780065
# 1        3141                Next Friday  11000000    9.337388
# 2        3344                My Dog Skip   7000000    5.675535
# 3         775                  Supernova  90000000    5.762037
# 4        4636               Chuck & Buck         0    0.812855
#
#                                 production_companies release_date  runtime  \
# 0  [{"name": "Cin\u00e9maginaire Inc.", "id": 280...   2000-01-01    112.0
# 1            [{"name": "New Line Cinema", "id": 12}]   2000-01-12     98.0
# 2  [{"name": "Alcon Entertainment", "id": 1088}, ...   2000-01-14     95.0
# 3  [{"name": "United Artists", "id": 60}, {"name"...   2000-01-14     91.0
# 4                                                 []   2000-01-21     96.0
#
#     revenue    status  vote_average  vote_count  Year
# 0         0  Released           6.7          11  2000
# ...

# %%
df['title'] = df['title'].str.replace(' ', '')

df.head()
# Out:
#    Unnamed: 0                   title    budget  popularity  \
# 0        2772  TheWidowofSaint-Pierre         0    1.780065
# 1        3141              NextFriday  11000000    9.337388
# 2        3344               MyDogSkip   7000000    5.675535
# 3         775               Supernova  90000000    5.762037
# 4        4636              Chuck&Buck         0    0.812855
#
#                                 production_companies release_date  runtime  \
# 0  [{"name": "Cin\u00e9maginaire Inc.", "id": 280...   2000-01-01    112.0
# 1            [{"name": "New Line Cinema", "id": 12}]   2000-01-12     98.0
# 2  [{"name": "Alcon Entertainment", "id": 1088}, ...   2000-01-14     95.0
# 3  [{"name": "United Artists", "id": 60}, {"name"...   2000-01-14     91.0
# 4                                                 []   2000-01-21     96.0
#
#     revenue    status  vote_average  vote_count  Year
# 0         0  Released           6.7          11  2000
# ...

# %%
merged_titles = df['title'].tolist()

# %%
# URL of page to be scraped
boxofficemojo = 'https://www.boxofficemojo.com/movies/?id='

for title in merged_titles:
    url1 = "https://www.boxofficemojo.com/movies/?id=" + title + ".htm"
    response1 = requests.get(url1)
    soup1 = BeautifulSoup(response1.text, 'html.parser')
    d_total_gross = soup1.find('div', {'class':['mp_box_content']})

    # Concatenate time string
    print('-----------------')
    print(d_total_gross)
    
#print(url1)
# Out:
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# -----------------
# None
# ...

# %%
# Retrieve page with the requests module
response1 = requests.get(url1)

# Create BeautifulSoup object; parse with 'lxml'
soup1 = BeautifulSoup(response1.text, 'html.parser')

# %%
merged_titles = df['title'].tolist()
boxofficemojo = 'https://www.boxofficemojo.com/movies/?id='
url = "https://www.boxofficemojo.com/movies/?id=" + merged_titles + ".htm"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-4f0f5384f396> in <module>()
#       1 merged_titles = df['title'].tolist()
#       2 boxofficemojo = 'https://www.boxofficemojo.com/movies/?id='
# ----> 3 url = "https://www.boxofficemojo.com/movies/?id=" + merged_titles + ".htm"
#       4
#       5
#
# TypeError: can only concatenate str (not "list") to str
