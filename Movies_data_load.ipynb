# %% [markdown]
# ## Data Load into MondoDB
#
# This script loads all movie data (TMDB and OMDB) to MongoDB

# %%
# Import all dependencies
from pymongo import MongoClient
import pandas as pd

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = MongoClient(conn)

# %%
# Define database and collection
db = client.moviesdb

# drop collections if already existing
db.omdb_api.drop()
db.tmdb_data.drop()
db.all_movies_data.drop()

#create / re-create collections
omdb_coll = db.omdb_api
tmdb_coll = db.tmdb_data
movies_coll = db.all_movies_data

# %% [markdown]
# ### Load OMDB data to MongoDB

# %%
omdb_api_data= pd.read_csv("omdb_api_cleaned.csv")

omdb_api_data.head()
# Out:
#    Unnamed: 0                      Title  Year                          Genre  \
# 0           0  The Widow of Saint-Pierre  2000        Drama, History, Romance
# 1           1                Nurse Betty  2000  Comedy, Crime, Drama, Romance
# 2           2                       Fiza  2000           Action, Crime, Drama
# 3           3                      Duets  2000  Comedy, Drama, Music, Romance
# 4           4                    Brother  2000         Crime, Drama, Thriller
#
#                                               Awards  Metascore   BoxOffice
# 0  Nominated for 1 Golden Globe. Another 3 wins &...       73.0          $0
# 1  Won 1 Golden Globe. Another 4 wins & 14 nomina...       69.0          $0
# 2                           4 wins & 18 nominations.        0.0          $0
# 3                                      1 nomination.       40.0  $4,262,782
# 4                              1 win & 1 nomination.       47.0          $0

# %%
omdb_api_data.count()
# Out:
# omdb_movie_id    3354
# Title            3354
# Year             3354
# Genre            3354
# Awards           3354
# Metascore        3354
# BoxOffice        3354
# dtype: int64

# %%
# rename col 1 to ID
omdb_api_data.rename(columns = {'Unnamed: 0': 'omdb_movie_id'}, inplace = True)
omdb_api_data.columns
# Out:
# Index(['omdb_movie_id', 'Title', 'Year', 'Genre', 'Awards', 'Metascore',
#        'BoxOffice'],
#       dtype='object')

# %%
omdb_dict=omdb_api_data.to_dict(orient="records")
print(omdb_dict)
# Out:
# [{'omdb_movie_id': 0, 'Title': 'The Widow of Saint-Pierre', 'Year': 2000, 'Genre': 'Drama, History, Romance', 'Awards': 'Nominated for 1 Golden Globe. Another 3 wins & 8 nominations.', 'Metascore': 73.0, 'BoxOffice': '$0'}, {'omdb_movie_id': 1, 'Title': 'Nurse Betty', 'Year': 2000, 'Genre': 'Comedy, Crime, Drama, Romance', 'Awards': 'Won 1 Golden Globe. Another 4 wins & 14 nominations.', 'Metascore': 69.0, 'BoxOffice': '$0'}, {'omdb_movie_id': 2, 'Title': 'Fiza', 'Year': 2000, 'Genre': 'Action, Crime, Drama', 'Awards': '4 wins & 18 nominations.', 'Metascore': 0.0, 'BoxOffice': '$0'}, {'omdb_movie_id': 3, 'Title': 'Duets', 'Year': 2000, 'Genre': 'Comedy, Drama, Music, Romance', 'Awards': '1 nomination.', 'Metascore': 40.0, 'BoxOffice': '$4,262,782'}, {'omdb_movie_id': 4, 'Title': 'Brother', 'Year': 2000, 'Genre': 'Crime, Drama, Thriller', 'Awards': '1 win & 1 nomination.', 'Metascore': 47.0, 'BoxOffice': '$0'}, {'omdb_movie_id': 5, 'Title': 'Sexy Beast', 'Year': 2000, 'Genre': 'Crime, Drama, Thriller', 'Awards': 'Nominated for 1 Oscar. Another 21 wins & 20 nominations.', 'Metascore': 79.0, 'BoxOffice': '$5,972,627'}, {'omdb_movie_id': 6, 'Title': 'Men of Honor', 'Year': 2000, 'Genre': 'Biography, Drama', 'Awards': '11 nominations.', 'Metascore': 56.0, 'BoxOffice': '$0'}, {'omdb_movie_id': 7, 'Title': 'Rugrats in Paris: The Movie', 'Year': 2000, 'Genre': 'Animation, Adventure, Comedy, Family, Romance', 'Awards': '3 wins & 7 nominations.', 'Metascore': 62.0, 'BoxOffice': '$0'}, {'omdb_movie_id': 81, 'Title': 'Nutty Professor II: The Klumps', 'Year': 2000, 'Genre': 'Comedy, Romance, Sci-Fi', 'Awards': '2 wins & 12 nominations.', 'Metascore': 38.0, 'BoxOffice': '$122,385,345'}, {'omdb_movie_id': 8, 'Title': 'The Way of the Gun', 'Year': 2000, 'Genre': 'Action, Crime, Drama, Thriller', 'Awards': 'none', 'Metascore': 49.0, 'BoxOffice': '$5,225,573'}, {'omdb_movie_id': 10, 'Title': 'Urban Legends: Final Cut', 'Year': 2000, 'Genre': 'Horror, Mystery, Thriller', 'Awards': '1 win & 1 nomination.', 'Metascore': 16.0, 'BoxOffice': '$21,007,274'}, {'omdb_movie_id': 11, 'Title': 'The Specials', 'Year': 2000, 'Genre': 'Action, Comedy, Fantasy, Sci-Fi', 'Awards': 'none', 'Metascore': 38.0, 'BoxOffice': '$0'}, {'omdb_movie_id': 12, 'Title': 'Woman on Top', 'Year': 2000, 'Genre': 'Comedy, Fantasy, Romance', 'Awards': '3 nominations.', 'Metascore': 41.0, 'BoxOffice': '$4,513,772'}, {'omdb_movie_id': 13, 'Title': 'The House of Mirth', 'Year': 2000, 'Genre': 'Romance, Drama', 'Awards': 'Nominated for 1 BAFTA Film Award. Another 6 wins & 28 nominations.', 'Metascore': 78.0, 'BoxOffice': '$0'}, {'omdb_movie_id': 14, 'Title': 'Remember the Titans', 'Year': 2000, 'Genre': 'Biography, Drama, Sport', 'Awards': '8 wins & 17 nominations.', 'Metascore': 48.0, 'BoxOffice': '$114,297,071'}, {'omdb_movie_id': 15, 'Title': 'George Washington', 'Year': 2000, 'Genre': 'Drama', 'Awards': '9 wins & 15 nominations.', 'Metascore': 82.0, 'BoxOffice': '$0'}, {'omdb_movie_id': 16, 'Title': 'Crouching Tiger, Hidden Dragon', 'Year': 2000, 'Genre': 'Action, Adventure, Fantasy, Romance', 'Awards': 'Won 4 Oscars. Another 96 wins & 130 nominations.', 'Metascore': 93.0, 'BoxOffice': '$0'}, {'omdb_movie_id': 9, 'Title': 'Almost Famous', 'Year': 2000, 'Genre': 'Adventure, Comedy, Drama, Music', 'Awards': 'Won 1 Oscar. Another 52 wins & 103 nominations.', 'Metascore': 90.0, 'BoxOffice': '$31,716,715'}, {'omdb_movie_id': 17, 'Title': 'Best in Show', 'Year': 2000, 'Genre': 'Comedy', 'Awards': 'Nominated for 1 Golden Globe. Another 11 wins & 13 nominations.', 'Metascore': 78.0, 'BoxOffice': '$16,574,225'}, {'omdb_movie_id': 18, 'Title': 'The Watcher', 'Year': 2000, 'Genre': 'Crime, Horror, Mystery, Thriller', 'Awards': '1 nomination.', 'Metascore': 22.0, 'BoxOffice': '$28,572,915'}, {'omdb_movie_id': 19, 'Title': 'Dungeons & Dragons', 'Year': 2000, 'Genre': 'Action, Adventure, Fantasy', 'Awards': '11 nominations.', 'Metascore': 14.0, 'BoxOffice': '$14,813,627'}, {'omdb_movie_id': 22 ...

# %%
omdb_ins_res = omdb_coll.insert_many(omdb_dict)

# %% [markdown]
# ### check if the load has been successfull
# - check the total records inserted
# - query a for a random record

# %%
# check the total records inserted
if(len(omdb_ins_res.inserted_ids) == omdb_api_data.Title.count()):
    print(f"Success!!! Total of {len(omdb_ins_res.inserted_ids)} inserted and it matches the DF count.")
else:
    print(f"Warning!!! Total records inserted {len(omdb_ins_res.inserted_ids)} is less than DF count of {omdb_api_data.Title.count()}")
# Out:
# Success!!! Total of 3354 inserted and it matches the DF count.

# %%
# Query a random record


print("Record pulled from Mongo")
print(omdb_coll.find_one({'Title' : omdb_api_data.Title[20]}))

print("Row from dataframe")

omdb_api_data.loc[omdb_api_data.Title == omdb_api_data.Title[20],]
# Out:
# Record pulled from Mongo
# {'_id': ObjectId('5c70678c2b0322428caa1b37'), 'omdb_movie_id': 19, 'Title': 'Dungeons & Dragons', 'Year': 2000, 'Genre': 'Action, Adventure, Fantasy', 'Awards': '11 nominations.', 'Metascore': 14.0, 'BoxOffice': '$14,813,627'}
# Row from dataframe
#     omdb_movie_id               Title  Year                       Genre  \
# 20             19  Dungeons & Dragons  2000  Action, Adventure, Fantasy
#
#              Awards  Metascore    BoxOffice
# 20  11 nominations.       14.0  $14,813,627

# %% [markdown]
# ### TMDB Load to MongoDB

# %%
dataFile = "TMDB_Cleaned.csv"
tmdb_df = pd.read_csv(dataFile)
tmdb_df.head()
# Out:
#    Unnamed: 0                      title    budget  popularity  \
# 0        2772  The Widow of Saint-Pierre         0    1.780065
# 1        3141                Next Friday  11000000    9.337388
# 2        3344                My Dog Skip   7000000    5.675535
# 3         775                  Supernova  90000000    5.762037
# 4        4636               Chuck & Buck         0    0.812855
#
#                                 production_companies release_date  runtime  \
# 0  [{"name": "Cin\u00e9maginaire Inc.", "id": 280...   2000-01-01    112.0
# 1            [{"name": "New Line Cinema", "id": 12}]   2000-01-12     98.0
# 2  [{"name": "Alcon Entertainment", "id": 1088}, ...   2000-01-14     95.0
# 3  [{"name": "United Artists", "id": 60}, {"name"...   2000-01-14     91.0
# 4                                                 []   2000-01-21     96.0
#
#     revenue    status  vote_average  vote_count  Year
# 0         0  Released           6.7          11  2000
# 1  59827328  Released           6.4         135  2000
# 2         0  Released           6.5          69  2000
# 3  14828081  Released           4.9         109  2000
# 4         0  Released           5.7          16  2000

# %%
# rename col 1 to ID
tmdb_df.rename(columns = {'Unnamed: 0': 'tmdb_movie_id'}, inplace = True)
tmdb_df.columns
# Out:
# Index(['tmdb_movie_id', 'title', 'budget', 'popularity',
#        'production_companies', 'release_date', 'runtime', 'revenue', 'status',
#        'vote_average', 'vote_count', 'Year'],
#       dtype='object')

# %%
insert_dict = tmdb_df.to_dict(orient = 'records')

# %%
len(insert_dict)
# Out:
# 3494

# %%
insert_tmdb_res = tmdb_coll.insert_many(insert_dict)

# %% [markdown]
# ### Verification : check if the load has been successfull
# - check the total records inserted
# - query a for a random record

# %%
# check the total records inserted
if(len(insert_tmdb_res.inserted_ids) == tmdb_df.title.count()):
    print(f"Success!!! Total of {len(omdb_ins_res.inserted_ids)} inserted and it matches the DF count.")
else:
    print(f"Warning!!! Total records inserted {len(omdb_ins_res.inserted_ids)} is less than DF count of {omdb_api_data.Title.count()}")
# Out:
# Success!!! Total of 3354 inserted and it matches the DF count.

# %%
# Query a random record


print("Record pulled from Mongo")
print(tmdb_coll.find_one({'title' : tmdb_df.title[370]}))

print("Row from dataframe")

tmdb_df.loc[tmdb_df.title == tmdb_df.title[370],]
# Out:
# Record pulled from Mongo
# {'_id': ObjectId('5c706a982b0322428caa29af'), 'tmdb_movie_id': 1496, 'title': 'Snow Dogs', 'budget': 33000000, 'popularity': 13.655735, 'production_companies': '[{"name": "Walt Disney Pictures", "id": 2}]', 'release_date': '2002-01-18', 'runtime': 99.0, 'revenue': 0, 'status': 'Released', 'vote_average': 5.3, 'vote_count': 185, 'Year': 2002}
# Row from dataframe
#      tmdb_movie_id      title    budget  popularity  \
# 370           1496  Snow Dogs  33000000   13.655735
#
#                             production_companies release_date  runtime  \
# 370  [{"name": "Walt Disney Pictures", "id": 2}]   2002-01-18     99.0
#
#      revenue    status  vote_average  vote_count  Year
# 370        0  Released           5.3         185  2002

# %% [markdown]
# ### Load Merged Movies data to MongoDB

# %%
all_mov_data= pd.read_csv("Movies_Merged.csv")

all_mov_data.head()
# Out:
#    Unnamed: 0                      Title    budget  popularity  \
# 0           0  The Widow of Saint-Pierre         0    1.780065
# 1           1                Next Friday  11000000    9.337388
# 2           2                My Dog Skip   7000000    5.675535
# 3           3                  Supernova  90000000    5.762037
# 4           4                Down to You   9000000    3.269459
#
#                                 production_companies release_date  runtime  \
# 0  [{"name": "Cin\u00e9maginaire Inc.", "id": 280...   2000-01-01    112.0
# 1            [{"name": "New Line Cinema", "id": 12}]   2000-01-12     98.0
# 2  [{"name": "Alcon Entertainment", "id": 1088}, ...   2000-01-14     95.0
# 3  [{"name": "United Artists", "id": 60}, {"name"...   2000-01-14     91.0
# 4              [{"name": "Miramax Films", "id": 14}]   2000-01-21     91.0
#
#     revenue    status  vote_average  vote_count  Year  \
# 0         0  Released           6.7          11  2000
# 1  59827328  Released           6.4         135  2000
# 2         0  Released           6.5          69  2000
# 3  14828081  Released           4.9         109  2000
# 4         0  Released           4.9          70  2000
#
#                       Genre  \
# 0   Drama, History, Romance
# 1                    Comedy
# 2     Comedy, Drama, Family
# 3  Horror, Sci-Fi, Thriller
# 4    Comedy, Drama, Romance
#
#                                               Awards  Metascore BoxOffice
# 0  Nominated for 1 Golden Globe. Another 3 wins &...       73.0        $0
# 1                                      1 nomination.       41.0        $0
# 2                            7 wins & 4 nominations.       61.0        $0
# 3                                               none       19.0        $0
# 4                             1 win & 3 nominations.       13.0        $0

# %%
all_mov_data.count()
# Out:
# Unnamed: 0              3139
# Title                   3139
# budget                  3139
# popularity              3139
# production_companies    3139
# release_date            3139
# runtime                 3139
# revenue                 3139
# status                  3139
# vote_average            3139
# vote_count              3139
# Year                    3139
# Genre                   3139
# Awards                  3139
# Metascore               3139
# BoxOffice               3139
# dtype: int64

# %%
# rename col 1 to ID
all_mov_data.rename(columns = {'Unnamed: 0': 'movie_id'}, inplace = True)
all_mov_data.columns
# Out:
# Index(['movie_id', 'Title', 'budget', 'popularity', 'production_companies',
#        'release_date', 'runtime', 'revenue', 'status', 'vote_average',
#        'vote_count', 'Year', 'Genre', 'Awards', 'Metascore', 'BoxOffice'],
#       dtype='object')

# %%
all_mov_dict=all_mov_data.to_dict(orient="records")
print(all_mov_dict)
# Out:
# [{'movie_id': 0, 'Title': 'The Widow of Saint-Pierre', 'budget': 0, 'popularity': 1.7800650000000002, 'production_companies': '[{"name": "Cin\\u00e9maginaire Inc.", "id": 280}, {"name": "Epithete films", "id": 6982}, {"name": "France2 Cin\\u00e9ma", "id": 7089}]', 'release_date': '2000-01-01', 'runtime': 112.0, 'revenue': 0, 'status': 'Released', 'vote_average': 6.7, 'vote_count': 11, 'Year': 2000, 'Genre': 'Drama, History, Romance', 'Awards': 'Nominated for 1 Golden Globe. Another 3 wins & 8 nominations.', 'Metascore': 73.0, 'BoxOffice': '$0'}, {'movie_id': 1, 'Title': 'Next Friday', 'budget': 11000000, 'popularity': 9.337388, 'production_companies': '[{"name": "New Line Cinema", "id": 12}]', 'release_date': '2000-01-12', 'runtime': 98.0, 'revenue': 59827328, 'status': 'Released', 'vote_average': 6.4, 'vote_count': 135, 'Year': 2000, 'Genre': 'Comedy', 'Awards': '1 nomination.', 'Metascore': 41.0, 'BoxOffice': '$0'}, {'movie_id': 2, 'Title': 'My Dog Skip', 'budget': 7000000, 'popularity': 5.675535, 'production_companies': '[{"name": "Alcon Entertainment", "id": 1088}, {"name": "Warner Bros.", "id": 6194}]', 'release_date': '2000-01-14', 'runtime': 95.0, 'revenue': 0, 'status': 'Released', 'vote_average': 6.5, 'vote_count': 69, 'Year': 2000, 'Genre': 'Comedy, Drama, Family', 'Awards': '7 wins & 4 nominations.', 'Metascore': 61.0, 'BoxOffice': '$0'}, {'movie_id': 3, 'Title': 'Supernova', 'budget': 90000000, 'popularity': 5.762037, 'production_companies': '[{"name": "United Artists", "id": 60}, {"name": "Metro-Goldwyn-Mayer (MGM)", "id": 8411}, {"name": "Hammerhead Productions", "id": 20375}, {"name": "Screenland Pictures", "id": 23587}]', 'release_date': '2000-01-14', 'runtime': 91.0, 'revenue': 14828081, 'status': 'Released', 'vote_average': 4.9, 'vote_count': 109, 'Year': 2000, 'Genre': 'Horror, Sci-Fi, Thriller', 'Awards': 'none', 'Metascore': 19.0, 'BoxOffice': '$0'}, {'movie_id': 4, 'Title': 'Down to You', 'budget': 9000000, 'popularity': 3.269459, 'production_companies': '[{"name": "Miramax Films", "id": 14}]', 'release_date': '2000-01-21', 'runtime': 91.0, 'revenue': 0, 'status': 'Released', 'vote_average': 4.9, 'vote_count': 70, 'Year': 2000, 'Genre': 'Comedy, Drama, Romance', 'Awards': '1 win & 3 nominations.', 'Metascore': 13.0, 'BoxOffice': '$0'}, {'movie_id': 5, 'Title': 'Urbania', 'budget': 0, 'popularity': 0.06515499999999999, 'production_companies': '[]', 'release_date': '2000-01-24', 'runtime': 103.0, 'revenue': 0, 'status': 'Released', 'vote_average': 5.2, 'vote_count': 10, 'Year': 2000, 'Genre': 'Drama', 'Awards': '5 wins & 4 nominations.', 'Metascore': 73.0, 'BoxOffice': '$0'}, {'movie_id': 6, 'Title': "Isn't She Great", 'budget': 36000000, 'popularity': 1.068453, 'production_companies': '[{"name": "Universal Pictures", "id": 33}, {"name": "Mutual Film Company", "id": 762}, {"name": "Toho Company", "id": 882}, {"name": "British Broadcasting Corporation (BBC)", "id": 3324}, {"name": "Marubeni", "id": 4650}, {"name": "Tele M\\u00fcnchen Fernseh Produktionsgesellschaft (TMG)", "id": 7237}, {"name": "Lobell/Bergman Productions", "id": 10513}]', 'release_date': '2000-01-28', 'runtime': 95.0, 'revenue': 3003296, 'status': 'Released', 'vote_average': 4.6, 'vote_count': 14, 'Year': 2000, 'Genre': 'Biography, Comedy, Drama', 'Awards': '2 nominations.', 'Metascore': 34.0, 'BoxOffice': '$0'}, {'movie_id': 7, 'Title': 'The Broken Hearts Club: A Romantic Comedy', 'budget': 1000000, 'popularity': 3.4241580000000003, 'production_companies': '[]', 'release_date': '2000-02-01', 'runtime': 94.0, 'revenue': 1744858, 'status': 'Released', 'vote_average': 6.3, 'vote_count': 25, 'Year': 2000, 'Genre': 'Comedy, Drama, Romance', 'Awards': '1 win & 1 nomination.', 'Metascore': 51.0, 'BoxOffice': '$0'}, {'movie_id': 8, 'Title': 'Scream 3', 'budget': 40000000, 'popularity': 24.992057, 'production_companies': '[{"name": "Konrad Pictures", "id": 85}, {"name": "Craven-Maddalena Films", "id": 1600}, {"name": "Dimension Films", "id": 7405}] ...

# %%
movies_ins_res = movies_coll.insert_many(all_mov_dict)

# %% [markdown]
# ### check if the load has been successfull
# - check the total records inserted
# - query a for a random record

# %%
# check the total records inserted
if(len(movies_ins_res.inserted_ids) == all_mov_data.Title.count()):
    print(f"Success!!! Total of {len(movies_ins_res.inserted_ids)} inserted and it matches the DF count.")
else:
    print(f"Warning!!! Total records inserted {len(movies_ins_res.inserted_ids)} is less than DF count of {all_mov_data.Title.count()}")
# Out:
# Success!!! Total of 3139 inserted and it matches the DF count.

# %%
# Query a random record


print("Record pulled from Mongo")
print(movies_coll.find_one({'Title' : all_mov_data.Title[120]}))

print("Row from dataframe")

all_mov_data.loc[all_mov_data.Title == all_mov_data.Title[120],]
# Out:
# Record pulled from Mongo
# {'_id': ObjectId('5c71791c2b032234f40c7439'), 'movie_id': 120, 'Title': 'Memento', 'budget': 9000000, 'popularity': 60.715151, 'production_companies': '[{"name": "Summit Entertainment", "id": 491}, {"name": "Newmarket Capital Group", "id": 506}, {"name": "Team Todd", "id": 598}, {"name": "I Remember Productions", "id": 34446}]', 'release_date': '2000-10-11', 'runtime': 113.0, 'revenue': 39723096, 'status': 'Released', 'vote_average': 8.1, 'vote_count': 4028, 'Year': 2000, 'Genre': 'Mystery, Thriller', 'Awards': 'Nominated for 2 Oscars. Another 56 wins & 55 nominations.', 'Metascore': 80.0, 'BoxOffice': '$23,844,220'}
# Row from dataframe
#      movie_id    Title   budget  popularity  \
# 120       120  Memento  9000000   60.715151
#
#                                   production_companies release_date  runtime  \
# 120  [{"name": "Summit Entertainment", "id": 491}, ...   2000-10-11    113.0
#
#       revenue    status  vote_average  vote_count  Year              Genre  \
# 120  39723096  Released           8.1        4028  2000  Mystery, Thriller
#
#                                                 Awards  Metascore    BoxOffice
# 120  Nominated for 2 Oscars. Another 56 wins & 55 n...       80.0  $23,844,220
