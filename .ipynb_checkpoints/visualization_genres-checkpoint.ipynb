# %%
# Import all required dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import csv

import pandas as pd

import numpy as np

import os

from datetime import datetime

import calendar
import matplotlib.pyplot as plt

import matplotlib as mpl
import seaborn as sns
from scipy.stats import linregress
import scipy.stats as stats
#from spread import variance, standard_deviation, zipped_z_scoresimport warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# File to Load (Remember to change these)
movies_data_load = "C:/Users/admin/Documents/SMU/etlproject/Movies_Merged.csv"

# Read the City and Ride Data
movies_data = pd.read_csv(movies_data_load)
movies_data.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'budget', 'popularity', 'production_companies',
#        'release_date', 'runtime', 'revenue', 'status', 'vote_average',
#        'vote_count', 'Year', 'Genre', 'Awards', 'Metascore', 'BoxOffice'],
#       dtype='object')

# %%
movies_data[['budget_fmt']] = movies_data[['budget']]/1000000

# %%
movies_data.describe()
# Out:
#         Unnamed: 0        budget   popularity      runtime       revenue  \
# count  3139.000000  3.139000e+03  3139.000000  3139.000000  3.139000e+03
# mean   1569.000000  3.411063e+07    23.968841   105.441822  9.435391e+07
# std     906.295574  4.548869e+07    36.296325    20.118782  1.810473e+08
# min       0.000000  0.000000e+00     0.001186     0.000000  0.000000e+00
# 25%     784.500000  1.200000e+06     5.646191    93.000000  0.000000e+00
# 50%    1569.000000  1.800000e+07    14.808304   103.000000  2.543429e+07
# 75%    2353.500000  4.500000e+07    31.378276   116.000000  1.030121e+08
# max    3138.000000  3.800000e+08   875.581305   214.000000  2.787965e+09
#
#        vote_average    vote_count         Year    Metascore   budget_fmt
# count   3139.000000   3139.000000  3139.000000  3139.000000  3139.000000
# mean       6.031666    796.403632  2007.951896    47.968143    34.110633
# std        1.141007   1348.122016     4.632021    23.383226    45.488692
# min        0.000000      0.000000  2000.000000     0.000000     0.000000
# 25%        5.500000     69.500000  2004.000000    35.000000     1.200000
# 50%        6.200000    291.000000  2008.000000    50.000000    18.000000
# 75%        6.700000    888.500000  2012.000000    65.000000    45.000000
# max       10.000000  13752.000000  2016.000000   100.000000   380.000000

# %%
sns.distplot(movies_data.budget_fmt,bins=3)

# %%
sns.distplot(movies_data.popularity,bins=50)

# %%
movies_data_cnt =movies_data[['Year','budget_fmt']]

movies_data_grp = movies_data_cnt.groupby(["Year"]).agg(["mean","count"])

movies_data_grp.reset_index(inplace=True)
movies_data_grp.set_axis(1, range(len(movies_data_grp.columns)))
movies_data_grp.rename(columns = {0:'Year',1 : 'Budget',2:'Count'}, inplace = True)
movies_data_grp
# Out:
#     Year     Budget  Count
# 0   2000  34.369032    155
# 1   2001  30.423505    173
# 2   2002  30.218797    186
# 3   2003  32.585774    159
# 4   2004  33.352222    188
# 5   2005  32.529705    188
# 6   2006  28.918914    221
# 7   2007  32.384793    181
# 8   2008  33.656306    206
# 9   2009  32.253958    219
# 10  2010  35.325930    207
# 11  2011  37.057548    202
# 12  2012  38.501459    182
# 13  2013  38.456436    199
# 14  2014  33.460302    209
# 15  2015  35.740716    178
# 16  2016  49.213837     86

# %%
fig, ax = plt.subplots(figsize = (9,7))
movie_budget_bar = sns.barplot(x="Year", y="Budget", data=movies_data_grp, color="#0098BF", alpha=0.5)
#ax2 = ax.twinx()
#movies_data_grp.plot(x="Year", y="Count", movie_budget_bar=ax2, legend=False, color="r")

plt.title("Movie Budget over Time(Years)")
plt.ylabel("Avg Budget ($M)")

# Save Figure
plt.savefig("C:/Users/admin/Documents/SMU/etlproject/static/images/Budget_bar.png")
plt.show()

# %%
movies_data['Genre_Type1'] = movies_data.Genre.apply(lambda s : s.split(",")[0])
movies_data
# Out:
#       Unnamed: 0                                      Title     budget  \
# 0              0                  The Widow of Saint-Pierre          0
# 1              1                                Next Friday   11000000
# 2              2                                My Dog Skip    7000000
# 3              3                                  Supernova   90000000
# 4              4                                Down to You    9000000
# 5              5                                    Urbania          0
# 6              6                            Isn't She Great   36000000
# 7              7  The Broken Hearts Club: A Romantic Comedy    1000000
# 8              8                                   Scream 3   40000000
# 9              9                                    Anatomy          0
# 10            10                                    Gun Shy   10000000
# 11            11                           The Tigger Movie   30000000
# 12            12                                  The Beach   40000000
# 13            13                                   Snow Day          0
# 14            14                                 Hanging Up   40000000
# 15            15                                Pitch Black   23000000
# 16            16                                Boiler Room   26000000
# 17            17                       The Whole Nine Yards   41300000
# 18            18                                Wonder Boys   35000000
# 19            19                             Reindeer Games   42000000
# 20            20                                  3 Strikes    6000000
# 21            21                  What Planet Are You From?   60000000
# 22            22                        The Next Best Thing   25000000
# 23            23                              Drowning Mona   16000000
# 24            24                            Mission to Mars   90000000
# 25            25                         The Young Unknowns          0
# 26            26                          The Perfect Storm  120000000
# 27            27                          Final Destination   23000000
# 28            28                              High Fidelity   30000000
# 29            29                         Digimon: The Movie    5500000
# ...          ...                                        ...        ...
# 3109        3109                           Now You See Me 2   90000000
# 3110        3110                              Me Before You   20000000
# 3111        3111                             The Neon Demon    7000000
# 3112        3112                       Central Intelligence   50000000
# 3113        3113                    The Secret Life of Pets   75000000
# 3114        3114               Independence Day: Resurgence  165000000
# 3115        3115                        Free State of Jones   50000000
# 3116        3116                               The Shallows   17000000
# 3117        3117                   The Purge: Election Year   10000000
# 3118        3118                       The Legend of Tarzan  180000000
# 3119        3119                           Star Trek Beyond  185000000
# 3120        3120                                Yoga Hosers    5000000
# 3121        3121                              The Dog Lover    2000000
# 3122        3122                              Sausage Party   19000000
# 3123        3123                            The Infiltrator   25000000
# 3124        3124                       Kickboxer: Vengeance   17000000
# 3125        3125                                 Lights Out    4900000
# 3126        3126                               Fight Valley   27000000
# 3127        3127                               Jason Bourne  120000000
# 3128        3128                                      Nerve   20000000
# 3129        3129                                   Bad Moms   20000000
# 3130        3130                              Shin Godzilla   15000000
# 3131        3131                                Indignation          0
# 3132        3132                              Suicide Squad  175000000
# 3133        3133                              Pete's Dragon   65000000
# 3134        3134                             Hands of Stone   20000000
# 3135        3135                                  Antibirth   35000000
# 3136        3136                                      Kicks          0
# 3137        3137                                 Mr. Church    8000000
# 3138        3138                      Two Lovers and a Bear          0
#
#       popularity                               production_companies  \
# 0       1.780065  [{"name": "Cin\u00e9maginaire Inc.", "id": 280...
# 1       9.337388            [{"name": "New Line Cinema", "id": 12}]
# 2       5.675535  [{"name": "Alcon Entertainment", "id": 1088}, ...
# 3       5.762037  [{"name": "United Artists", "id": 60}, {"name"...
# 4       3.269459              [{"name": "Miramax Films", "id": 14}]
# 5       0.065155                                                 []
# 6       1.068453  [{"name": "Universal Pictures", "id": 33}, {"n...
# 7       3.424158                                                 []
# 8      24.992057  [{"name": "Konrad Pictures", "id": 85}, {"name...
# 9       5.025938  [{"name": "Claussen + W\u00f6bke Filmproduktio...
# 10      3.988432  [{"name": "Hollywood Pictures", "id": 915}, {"...
# 11      9.829859        [{"name": "Walt Disney Pictures", "id": 2}]
# 12     41.362082             [{"name": "Figment Films", "id": 359}]
# 13      7.964289  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 14      3.415534  [{"name": "Laurence Mark Productions", "id": 4...
# 15     18.493202  [{"name": "Interscope Communications", "id": 1...
# 16     11.233081            [{"name": "New Line Cinema", "id": 12}]
# 17     23.441135  [{"name": "Franchise Pictures", "id": 1403}, {...
# 18      9.011729  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 19     11.470135  [{"name": "Dimension Films", "id": 7405}, {"na...
# 20      1.433692                                                 []
# 21      2.275331           [{"name": "Columbia Pictures", "id": 5}]
# 22      3.707511  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 23      3.021835  [{"name": "Code Entertainment", "id": 14589}, ...
# 24     16.058284  [{"name": "Spyglass Entertainment", "id": 158}...
# 25      0.004922                                                 []
# 26     25.752118  [{"name": "Warner Bros.", "id": 6194}, {"name"...
# 27     38.799596  [{"name": "New Line Cinema", "id": 12}, {"name...
# 28     23.982956  [{"name": "Buena Vista", "id": 32}, {"name": "...
# 29      3.738700  [{"name": "Saban Entertainment", "id": 2106}, ...
# ...          ...                                                ...
# 3109   51.535701  [{"name": "Summit Entertainment", "id": 491}, ...
# 3110   53.161905  [{"name": "New Line Cinema", "id": 12}, {"name...
# 3111   38.150787  [{"name": "Bold Films", "id": 2266}, {"name": ...
# 3112   45.318703  [{"name": "New Line Cinema", "id": 12}, {"name...
# 3113   31.482872  [{"name": "Universal Pictures", "id": 33}, {"n...
# 3114   48.775723  [{"name": "Twentieth Century Fox Film Corporat...
# 3115   21.589393  [{"name": "Larger Than Life Productions", "id"...
# 3116   60.829621  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3117   53.727146  [{"name": "Universal Pictures", "id": 33}, {"n...
# 3118   42.741719  [{"name": "Village Roadshow Pictures", "id": 7...
# 3119   65.352913  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 3120    8.618793  [{"name": "Invincible Pictures Corp.", "id": 1...
# 3121    1.193219  [{"name": "ESX Productions", "id": 37081}, {"n...
# 3122   66.242737  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3123   24.672234              [{"name": "Good Films", "id": 68620}]
# 3124    6.526588  [{"name": "Radar Pictures", "id": 14718}, {"na...
# 3125   48.170508  [{"name": "New Line Productions", "id": 8781},...
# 3126    1.224105   [{"name": "Cinestyle Media Group", "id": 74413}]
# 3127   62.641286  [{"name": "The Kennedy/Marshall Company", "id"...
# 3128   62.933899  [{"name": "Lionsgate", "id": 1632}, {"name": "...
# 3129   42.512296  [{"name": "STX Entertainment", "id": 47729}, {...
# 3130    9.476999  [{"name": "Cine Bazar", "id": 5896}, {"name": ...
# 3131    5.625989             [{"name": "Likely Story", "id": 1785}]
# 3132   90.237920  [{"name": "DC Comics", "id": 429}, {"name": "D...
# 3133   31.974359  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 3134    7.444189  [{"name": "Weinstein Company, The", "id": 7289...
# 3135    3.674294  [{"name": "Hideaway Pictures", "id": 20068}, {...
# 3136    3.467923  [{"name": "Bystorm Films", "id": 2903}, {"name...
# 3137    7.828459  [{"name": "Envision Media Arts", "id": 19456},...
# 3138    3.139294                                                 []
#
#      release_date  runtime    revenue    status  vote_average  vote_count  \
# 0      2000-01-01    112.0          0  Released           6.7          11
# 1      2000-01-12     98.0   59827328  Released           6.4         135
# 2      2000-01-14     95.0          0  Released           6.5          69
# 3      2000-01-14     91.0   14828081  Released           4.9         109
# 4      2000-01-21     91.0          0  Released           4.9          70
# 5      2000-01-24    103.0          0  Released           5.2          10
# 6      2000-01-28     95.0    3003296  Released           4.6          14
# 7      2000-02-01     94.0    1744858  Released           6.3          25
# 8      2000-02-03    116.0  161834276  Released           5.7         736
# 9      2000-02-03    103.0          0  Released           6.1          61
# 10     2000-02-04    101.0    1631839  Released           5.4          24
# 11     2000-02-11     77.0   45554533  Released           6.3         143
# 12     2000-02-11    119.0  144056873  Released           6.3        1233
# 13     2000-02-11     89.0          0  Released           4.8          51
# 14     2000-02-16     94.0   36037909  Released           5.0          40
# 15     2000-02-18    108.0   53187659  Released           6.7        1789
# 16     2000-02-18    118.0   28780255  Released           6.5         201
# 17     2000-02-18     98.0  106371651  Released           6.2         531
# 18     2000-02-22    111.0          0  Released           6.9         161
# 19     2000-02-25    124.0   32168970  Released           5.4         173
# 20     2000-03-01     82.0    9000000  Released           5.9          15
# 21     2000-03-03    105.0          0  Released           5.4          37
# 22     2000-03-03    108.0   24362772  Released           4.3          29
# 23     2000-03-03     96.0   15427192  Released           5.4          43
# 24     2000-03-10    114.0   60874615  Released           5.7         369
# 25     2000-03-12     87.0          0  Released           0.0           0
# 26     2000-03-15    130.0  325756637  Released           6.2         597
# 27     2000-03-16     98.0   53302314  Released           6.4        1378
# 28     2000-03-17    113.0   47126295  Released           7.0         628
# 29     2000-03-17     82.0          0  Released           6.2          72
# ...           ...      ...        ...       ...           ...         ...
# 3109   2016-06-02    129.0  334901337  Released           6.7        3235
# 3110   2016-06-02    110.0  207945075  Released           7.6        2562
# 3111   2016-06-08    117.0    1333124  Released           6.4         887
# 3112   2016-06-15    107.0  216972543  Released           6.2        1650
# 3113   2016-06-18     87.0  875958308  Released           5.9        3462
# 3114   2016-06-22    120.0  389681935  Released           4.9        2491
# 3115   2016-06-24    139.0   25035950  Released           6.6         428
# 3116   2016-06-24     86.0  119100758  Released           6.2        1567
# 3117   2016-06-29    105.0  118587880  Released           6.1        1306
# 3118   2016-06-29    109.0  356743061  Released           5.5        2430
# 3119   2016-07-07    122.0  343471816  Released           6.6        2568
# 3120   2016-07-08     88.0          0  Released           4.7         102
# 3121   2016-07-08    101.0          0  Released           5.3           6
# 3122   2016-07-11     83.0  140752617  Released           5.6        2238
# 3123   2016-07-13    127.0   15436808  Released           6.6         573
# 3124   2016-07-14     90.0          0  Released           4.5          99
# 3125   2016-07-21     81.0   44107032  Released           6.3        1129
# 3126   2016-07-22     90.0          0  Released           3.9           8
# 3127   2016-07-27    123.0  415484914  Released           5.9        2341
# 3128   2016-07-27     96.0   83707310  Released           7.1        2181
# 3129   2016-07-28    100.0  183936074  Released           6.3        1252
# 3130   2016-07-29    120.0   77000000  Released           6.5         143
# 3131   2016-07-29    110.0          0  Released           6.8          69
# 3132   2016-08-02    123.0  745000000  Released           5.9        7458
# 3133   2016-08-10    102.0  143695338  Released           6.2         679
# 3134   2016-08-26    105.0          0  Released           6.1         109
# 3135   2016-09-02     94.0          0  Released           4.8          40
# 3136   2016-09-09     80.0          0  Released           7.5          18
# 3137   2016-09-16    104.0          0  Released           7.0         129
# 3138   2016-10-02     96.0          0  Released           6.8          27
#
#       Year                                              Genre  \
# 0     2000                            Drama, History, Romance
# 1     2000                                             Comedy
# 2     2000                              Comedy, Drama, Family
# 3     2000                           Horror, Sci-Fi, Thriller
# 4     2000                             Comedy, Drama, Romance
# 5     2000                                              Drama
# 6     2000                           Biography, Comedy, Drama
# 7     2000                             Comedy, Drama, Romance
# 8     2000                                    Horror, Mystery
# 9     2000                                   Horror, Thriller
# 10    2000                             Comedy, Crime, Romance
# 11    2000          Animation, Comedy, Drama, Family, Musical
# 12    2000                Adventure, Drama, Romance, Thriller
# 13    2000                          Adventure, Comedy, Family
# 14    2000                                      Comedy, Drama
# 15    2000                                     Horror, Sci-Fi
# 16    2000                             Crime, Drama, Thriller
# 17    2000                                      Comedy, Crime
# 18    2000                                      Comedy, Drama
# 19    2000          Action, Adventure, Crime, Drama, Thriller
# 20    2000                                             Comedy
# 21    2000                                     Comedy, Sci-Fi
# 22    2000                             Comedy, Drama, Romance
# 23    2000                             Comedy, Crime, Mystery
# 24    2000                        Adventure, Sci-Fi, Thriller
# 25    2000                                              Drama
# 26    2000                 Action, Adventure, Drama, Thriller
# 27    2000                                   Horror, Thriller
# 28    2000                      Comedy, Drama, Music, Romance
# 29    2000       Animation, Action, Adventure, Family, Sci-Fi
# ...    ...                                                ...
# 3109  2016  Action, Adventure, Comedy, Crime, Mystery, Thr...
# 3110  2016                                     Drama, Romance
# 3111  2016                                   Horror, Thriller
# 3112  2016                              Action, Comedy, Crime
# 3113  2016               Animation, Adventure, Comedy, Family
# 3114  2016                          Action, Adventure, Sci-Fi
# 3115  2016             Action, Biography, Drama, History, War
# 3116  2016                            Drama, Horror, Thriller
# 3117  2016                   Action, Horror, Sci-Fi, Thriller
# 3118  2016         Action, Adventure, Drama, Fantasy, Romance
# 3119  2016                Action, Adventure, Sci-Fi, Thriller
# 3120  2016          Action, Comedy, Fantasy, Horror, Thriller
# 3121  2016                                              Drama
# 3122  2016              Animation, Adventure, Comedy, Fantasy
# 3123  2016                  Biography, Crime, Drama, Thriller
# 3124  2016                        Action, Crime, Drama, Sport
# 3125  2016                   Drama, Horror, Mystery, Thriller
# 3126  2016                                      Action, Drama
# 3127  2016                                   Action, Thriller
# 3128  2016  Action, Adventure, Crime, Drama, Mystery, Thri...
# 3129  2016                                             Comedy
# 3130  2016           Action, Adventure, Drama, Horror, Sci-Fi
# 3131  2016                                     Drama, Romance
# 3132  2016                 Action, Adventure, Fantasy, Sci-Fi
# 3133  2016         Action, Adventure, Comedy, Family, Fantasy
# 3134  2016                    Action, Biography, Drama, Sport
# 3135  2016                                             Horror
# 3136  2016                                   Adventure, Drama
# 3137  2016                                      Comedy, Drama
# 3138  2016                          Adventure, Drama, Romance
#
#                                                  Awards  Metascore  \
# 0     Nominated for 1 Golden Globe. Another 3 wins &...       73.0
# 1                                         1 nomination.       41.0
# 2                               7 wins & 4 nominations.       61.0
# 3                                                  none       19.0
# 4                                1 win & 3 nominations.       13.0
# 5                               5 wins & 4 nominations.       73.0
# 6                                        2 nominations.       34.0
# 7                                 1 win & 1 nomination.       51.0
# 8                               5 wins & 5 nominations.       56.0
# 9                                1 win & 3 nominations.       33.0
# 10                                                 none       42.0
# 11                                       4 nominations.       53.0
# 12                                       7 nominations.       43.0
# 13                                       4 nominations.       34.0
# 14                               2 wins & 1 nomination.       33.0
# 15                              2 wins & 4 nominations.       49.0
# 16                               1 win & 9 nominations.       63.0
# 17                                       5 nominations.       47.0
# 18       Won 1 Oscar. Another 19 wins & 46 nominations.       73.0
# 19                                       3 nominations.       37.0
# 20                                                 none       11.0
# 21                                        1 nomination.       41.0
# 22                             3 wins & 10 nominations.       25.0
# 23                                        1 nomination.       25.0
# 24                                        1 nomination.       34.0
# 25                                               1 win.       43.0
# 26    Nominated for 2 Oscars. Another 4 wins & 25 no...       59.0
# 27                              3 wins & 3 nominations.       36.0
# 28    Nominated for 1 Golden Globe. Another 3 wins &...       79.0
# 29                                                 none       20.0
# ...                                                 ...        ...
# 3109                                     4 nominations.       46.0
# 3110                            6 wins & 6 nominations.       51.0
# 3111                          18 wins & 31 nominations.       51.0
# 3112                            2 wins & 8 nominations.       52.0
# 3113                           4 wins & 15 nominations.       61.0
# 3114                           3 wins & 16 nominations.       32.0
# 3115                            3 wins & 4 nominations.       53.0
# 3116                                    15 nominations.       59.0
# 3117                                     6 nominations.       55.0
# 3118                            2 wins & 4 nominations.       44.0
# 3119  Nominated for 1 Oscar. Another 3 wins & 27 nom...       68.0
# 3120                                      1 nomination.       23.0
# 3121                                               none       35.0
# 3122                            1 win & 24 nominations.       66.0
# 3123                                               none       66.0
# 3124                                               none       37.0
# 3125                            3 wins & 9 nominations.       58.0
# 3126                                               none       22.0
# 3127                           3 wins & 20 nominations.       58.0
# 3128                                     5 nominations.       58.0
# 3129                            3 wins & 5 nominations.       60.0
# 3130                           13 wins & 9 nominations.       67.0
# 3131                                     4 nominations.       78.0
# 3132     Won 1 Oscar. Another 16 wins & 37 nominations.       40.0
# 3133                            2 wins & 5 nominations.       71.0
# 3134                                               none       54.0
# 3135                                     2 nominations.       56.0
# 3136                            4 wins & 2 nominations.       69.0
# 3137                                     3 nominations.       37.0
# 3138                            2 wins & 5 nominations.       61.0
#
#          BoxOffice  budget_fmt Genre_Type1
# 0               $0         0.0       Drama
# 1               $0        11.0      Comedy
# 2               $0         7.0      Comedy
# 3               $0        90.0      Horror
# 4               $0         9.0      Comedy
# 5               $0         0.0       Drama
# 6               $0        36.0   Biography
# 7               $0         1.0      Comedy
# 8               $0        40.0      Horror
# 9               $0         0.0      Horror
# 10              $0        10.0      Comedy
# 11              $0        30.0   Animation
# 12              $0        40.0   Adventure
# 13              $0         0.0   Adventure
# 14              $0        40.0      Comedy
# 15              $0        23.0      Horror
# 16              $0        26.0       Crime
# 17     $57,262,492        41.3      Comedy
# 18              $0        35.0      Comedy
# 19              $0        42.0      Action
# 20              $0         6.0      Comedy
# 21              $0        60.0      Comedy
# 22              $0        25.0      Comedy
# 23              $0        16.0      Comedy
# 24              $0        90.0   Adventure
# 25              $0         0.0       Drama
# 26              $0       120.0      Action
# 27              $0        23.0      Horror
# 28              $0        30.0      Comedy
# 29      $9,009,288         5.5   Animation
# ...            ...         ...         ...
# 3109   $65,030,563        90.0      Action
# 3110   $56,228,651        20.0       Drama
# 3111            $0         7.0      Horror
# 3112  $127,380,061        50.0      Action
# 3113  $368,305,960        75.0   Animation
# 3114  $103,137,295       165.0      Action
# 3115            $0        50.0      Action
# 3116   $55,121,623        17.0       Drama
# 3117            $0        10.0      Action
# 3118  $126,585,313       180.0      Action
# 3119  $158,804,470       185.0      Action
# 3120            $0         5.0      Action
# 3121            $0         2.0       Drama
# 3122   $97,661,826        19.0   Animation
# 3123   $15,425,870        25.0   Biography
# 3124            $0        17.0      Action
# 3125   $67,235,683         4.9       Drama
# 3126            $0        27.0      Action
# 3127  $162,162,120       120.0      Action
# 3128   $38,562,379        20.0      Action
# 3129  $113,217,955        20.0      Comedy
# 3130    $1,908,028        15.0      Action
# 3131    $3,399,841         0.0       Drama
# 3132  $325,021,779       175.0      Action
# 3133   $76,228,119        65.0      Action
# 3134    $4,711,216        20.0      Action
# 3135            $0        35.0      Horror
# 3136      $145,368         0.0   Adventure
# 3137      $685,143         8.0      Comedy
# 3138            $0         0.0   Adventure
#
# [3139 rows x 18 columns]

# %%
movies_genre =movies_data[['Title','Genre_Type1']]

movies_genre_grp = movies_genre.groupby(["Genre_Type1"]).agg(["count"])


movies_genre_grp.reset_index(inplace=True)
movies_genre_grp.columns
movies_genre_grp.set_axis(1, range(len(movies_genre.columns)))
movies_genre_grp.rename(columns = {0:'Genre Category',1:"Movie Count"}, inplace = True)
top_category=movies_genre_grp.head(5)
top_category
# Out:
#   Genre Category  Movie Count
# 0         Action          700
# 1      Adventure          181
# 2      Animation          183
# 3      Biography          175
# 4         Comedy          827

# %%
fig, ax = plt.subplots(figsize = (9,7))
movies_genre_bar = sns.barplot(x="Genre Category", y="Movie Count", data=top_category, orient="v", alpha=0.5)


plt.title(" Top Five Movie Category")
plt.xlabel("Category",)
plt.ylabel("Movie #")
plt.legend

# Save Figure
plt.savefig("C:/Users/admin/Documents/SMU/etlproject/static/images/TopFiveMovie_Category.png")
plt.show()

# %%
# Labels for the sections of our pie chart
Category = ["Action","Adventure","Animation","Biography","Comedy","Crime","Documentary","Drama","Family","Fantasy","Horror","Musical","Mystery","Romance","Sci-Fi","Thriller","Short","Western"]

# The values of each section of the pie chart
Movie_Count = [700,181,183,175,827, 200,92,591,4,10,136,1,16,5,5,2,8,3]

# The colors of each section of the pie chart


# Tells matplotlib to seperate the "Python" section from the others
explode = (0.1, 0, 0, 0)

# %%
plt.pie(Movie_Count,Category=labels,autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-45693bfc6e80> in <module>()
# ----> 1 plt.pie(Movie_Count,Category=labels,autopct="%1.1f%%", shadow=True, startangle=140)
#
# NameError: name 'labels' is not defined

# %%
budget_bins = [0, movies_data.describe().loc['25%','budget'], movies_data.describe().loc['50%','budget'],

       movies_data.describe().loc['75%','budget'], movies_data.describe().loc['max','budget']+100]

budget_bins

# %%
movies_data.count()

# %%
movies_noRevenue2 = movies_data[movies_data.budget <= 0 ].count()
print(movies_noRevenue2)
