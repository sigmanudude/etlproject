# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# File to Load (Remember to Change These)
file_to_load = "~/Desktop/Movies_Merged.csv"

# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(file_to_load)

df.head()
# Out:
#    Unnamed: 0                      Title    budget  popularity  \
# 0           0  The Widow of Saint-Pierre         0    1.780065
# 1           1                Next Friday  11000000    9.337388
# 2           2                My Dog Skip   7000000    5.675535
# 3           3                  Supernova  90000000    5.762037
# 4           4                Down to You   9000000    3.269459
#
#                                 production_companies release_date  runtime  \
# 0  [{"name": "Cin\u00e9maginaire Inc.", "id": 280...   2000-01-01    112.0
# 1            [{"name": "New Line Cinema", "id": 12}]   2000-01-12     98.0
# 2  [{"name": "Alcon Entertainment", "id": 1088}, ...   2000-01-14     95.0
# 3  [{"name": "United Artists", "id": 60}, {"name"...   2000-01-14     91.0
# 4              [{"name": "Miramax Films", "id": 14}]   2000-01-21     91.0
#
#     revenue    status  vote_average  vote_count  Year  \
# 0         0  Released           6.7          11  2000
# 1  59827328  Released           6.4         135  2000
# 2         0  Released           6.5          69  2000
# 3  14828081  Released           4.9         109  2000
# 4         0  Released           4.9          70  2000
#
#                       Genre  \
# 0   Drama, History, Romance
# 1                    Comedy
# 2     Comedy, Drama, Family
# 3  Horror, Sci-Fi, Thriller
# 4    Comedy, Drama, Romance
#
#                                               Awards  Metascore BoxOffice
# 0  Nominated for 1 Golden Globe. Another 3 wins &...       73.0        $0
# 1                                      1 nomination.       41.0        $0
# 2                            7 wins & 4 nominations.       61.0        $0
# 3                                               none       19.0        $0
# 4                             1 win & 3 nominations.       13.0        $0

# %%
# Filter the DataFrame down only to those columns to chart
title_rev = df[["Title","revenue"]]

# Set the index to be "State" so they will be used as labels
#title_rev = df.set_index("revenue")

title_rev.head()
# Out:
#                        Title   revenue
# 0  The Widow of Saint-Pierre         0
# 1                Next Friday  59827328
# 2                My Dog Skip         0
# 3                  Supernova  14828081
# 4                Down to You         0

# %%
revenue_df = title_rev[title_rev.revenue != 0].sort_values(by='revenue', ascending=False)

revenue_df['revenue'] = revenue_df[['revenue']] / 1000000

revenue_df = revenue_df.set_index("Title")

top_15 = revenue_df.head(15)

# %%
top_15
# Out:
#                                                    revenue
# Title
# Avatar                                         2787.965087
# The Avengers                                   1519.557910
# Jurassic World                                 1513.528810
# Furious 7                                      1506.249360
# Avengers: Age of Ultron                        1405.403694
# Frozen                                         1274.219009
# Iron Man 3                                     1215.439994
# Minions                                        1156.730962
# Captain America: Civil War                     1153.304495
# Transformers: Dark of the Moon                 1123.746996
# The Lord of the Rings: The Return of the King  1118.888979
# Skyfall                                        1108.561013
# Transformers: Age of Extinction                1091.405097
# The Dark Knight Rises                          1084.939099
# Toy Story 3                                    1066.969703

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
top_15.plot(kind="bar", figsize=(20,3))

# Set a title for the chart
plt.title("Top 10 Highest Grossing Films")
plt.xlabel("Title")
plt.ylabel("Revenue / 1000000")
#plt.savefig("~/Desktop/classwork/etlproject/static/images/top5.png")
plt.savefig("C:/Users/justi/Desktop/classwork/etlproject/static/Top15grossing.png")
plt.show()

# %%
least_revenue_df = title_rev[title_rev.revenue != 0].sort_values(by='revenue', ascending=True)

least_revenue_df['revenue'] = least_revenue_df[['revenue']] / 1000000

least_revenue_df = least_revenue_df.set_index("Title")

flops = least_revenue_df.head(15)

flops
# Out:
#                                      revenue
# Title
# Bran Nue Dae                        0.000007
# Of Horses and Men                   0.000011
# The Cookout                         0.000012
# Chasing Liberty                     0.000012
# Tae Guk Gi: The Brotherhood of War  0.000015
# In the Cut                          0.000023
# Lake of Fire                        0.000025
# Death at a Funeral                  0.000046
# My Baby's Daddy                     0.000051
# When Did You Last See Your Father?  0.000092
# Rugrats in Paris: The Movie         0.000103
# Khiladi 786                         0.000126
# Irreversible                        0.000792
# Eddie: The Sleepwalking Cannibal    0.001632
# Mi America                          0.003330

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
flops.plot(kind="bar", figsize=(20,3))

# Set a title for the chart
plt.title("15 Least Grossing")
plt.xlabel("Title")
plt.ylabel("Revenue / 1000000")
plt.savefig("C:/Users/justi/Desktop/classwork/etlproject/static/15flops.png")
plt.show()
